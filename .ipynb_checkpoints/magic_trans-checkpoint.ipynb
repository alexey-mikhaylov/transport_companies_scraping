# %% [markdown]
# # Компания: Magic Trans (https://magic-trans.ru/)

# %%
import requests
import json
import re

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"

# %% [markdown]
# ## Публичный API (https://magic-trans.ru/developers/)

# %%
# идентификация населённых пунктов
# подробнее про API Magic Trans см. здесь: https://magic-trans.ru/developers/API_202210.DOCX
url = "https://magic-trans.ru/api/v1/dictionary/getCityList.json"
headers = {"User-Agent": user_agent}
input_data = {"name": "Казань"}
resp = requests.get(url=url, params=input_data, headers=headers)
resp.raise_for_status()
output_data = resp.json()
output_data
# Out:
# {'status': True,
#  'error': 0,
#  'message': None,
#  'result': [{'id': '265742',
#    'name': 'Аэропорт (Казань), Республика Татарстан',
#    'terminal': False,
#    'delivery': True},
#   {'id': '2514', 'name': 'Казань', 'terminal': True, 'delivery': True}]}

# %%
# расчёт стоимости и сроков доставки
url = "https://magic-trans.ru/api/v1/delivery/calculate.json"
headers = {"User-Agent": user_agent}
input_data = {"from": "2514",
              "to": "3161",
              "regime": "N",
              "price": "0",
              "items[0][count]": "1",
              "items[0][weight]": "5.5",
              "items[0][volume]": "0.001"}
resp = requests.get(url=url, params=input_data, headers=headers)
resp.raise_for_status()
output_data = resp.json()
output_data
# Out:
# {'status': True,
#  'error': 0,
#  'message': None,
#  'result': {'price': 590,
#   'min': 4,
#   'max': 7,
#   'routes': [{'from': {'id': '2514', 'name': 'Казань'},
#     'to': {'id': '3161', 'name': 'Саратов'},
#     'price': 590,
#     'min': '4',
#     'max': '7'}]}}

# %% [markdown]
# ## Калькулятор на сайте (https://magic-trans.ru/calculator/)

# %%
# идентификация населённых пунктов
url = "https://magic-trans.ru/include/mt-get-information-by-city.php"
headers = {"accept": "*/*",
           "x-requested-with": "XMLHttpRequest",
           "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
           "User-Agent": user_agent}
input_data = {"city": "Казань"}
resp = requests.post(url=url, data=input_data, headers=headers)
resp.raise_for_status()
output_data = resp.json()
output_data
# Out:
# {'city': 'Казань',
#  'type': 'terminal',
#  'terminal': 'Казань',
#  'location': ['г. Казань, ул. Техническая д. 21\r\n(максимальный вес 1 места, который может обработать склад: 1800 кг) '],
#  'error': 0,
#  'dissalow_terminal': None,
#  'actions': [[]],
#  'actions_note': [],
#  'is_terminal': True}

# %%
# расчёт стоимости и сроков доставки
url = "https://magic-trans.ru/include/mt-calculation-full.php"
headers = {"Accept": "*/*",
           "Accept-Encoding": "gzip, deflate, br",
           "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
           "User-Agent": user_agent}
input_data = {"city_form": "Москва",
              "city_to": "Ноябрьск",
              "take_cargo": "true",
              "give_cargo": "true",
              "json_params_cargo": '{"0":{"packing": "none","palletizing":"нет","long":"","high":"","width":"","weight":"30","count":"1","volume":"0.001"}}',
              "json_other_params": '{"box":"","bag":"","save":"0","sensitive_cargo":false,"return_document":false}',
              "to_network": "false",
              "from_person": "true",
              "to_person": "true",
              "delivery_date": ""}
resp = requests.post(url=url, data=input_data, headers=headers)
resp.raise_for_status()
output_data = resp.json()
output_data
# Out:
# {'newDate': {'days': 'от 6 суток',
#   'data': {'departureDates': {'dates': ['06 May',
#      '07 May',
#      '08 May',
#      '09 May',
#      '10 May',
#      '11 May',
#      '12 May'],
#     'days': ['ПН', 'ВТ', 'СР', 'ЧТ', 'ПТ', 'СБ', 'ВС']},
#    'recipientDates': ['13 May',
#     '13 May',
#     '15 May',
#     '15 May',
#     '17 May',
#     '17 May',
#     '20 May'],
#    'recipientDays': ['ПН', 'ПН', 'СР', 'СР', 'ПТ', 'ПТ', 'ПН'],
#    'calculateDates': ['13 мая',
#     '13 мая',
#     '15 мая',
#     '15 мая',
#     '17 мая',
#     '17 мая',
#     '20 мая'],
#    'calculateDate': '17 мая'},
#   'currentWay': {'target': 'Ноябрьск',
#    'isMT': 'Y',
#    'points': ['247940', '247954'],
#    'defaultPeriod': 6,
#    'days': [{'name': 'ПН', 'value': 7, 'coefficient': 1},
#     {'name': 'ВТ', 'value': 6, 'coefficient': 0},
#     {'name': 'СР', 'value': 7, 'coefficient': 1},
#     {'name': 'ЧТ', 'value': 6, 'coefficient': 0},
#     {'name': 'ПТ', 'value': 7, 'coefficient': 1},
#     {'name': 'СБ', 'value': 6, 'coefficient': 0},
#     {'name': 'ВС', 'value': 8, 'coefficient': 2}],
#    'id': ['247940', '247954']},
#   'date': '17 мая',
#   'date1': None},
#  'k1t': [],
#  'termForCalculator': [172286],
#  'MTDiscountStatus': None,
#  'MTDiscountDirection': None,
#  'MTDiscountValue': None,
#  'MTDiscountTypeWeight': None,
#  'MTDiscountTypeSize': None,
#  'userID': None,
#  'k1Test': {'ip': '5.164.228.7', 'over': ['second']},
#  'partDelivery': False,
#  'params_cargo': [{'long': 0,
#    'high': 0,
#    'width': 0,
#    'count': 1,
#    'weight': 30,
#    'unit_weight': 30,
#    'volume': 0.001,
#    'unit_volume': 0.001,
#    'packing': 'none',
#    'pack_cost': 0,
#    'overload': 0,
#    'overload_type': '',
#    'weight_old': 30,
#    'volume_old': 0.001,
#    'palletizing': 'нет'}],
#  'other_params': {'bag': 0,
#   'box': 0,
#   'save': 0,
#   'sensitive_cargo': False,
#   'return_document': False},
#  'mode_calculation': False,
#  'result_params_cargo': [{'long': 0,
#    'high': 0,
#    'width': 0,
#    'count': 1,
#    'weight': 30,
#    'weight_old': 30,
#    'volume': 0.001,
#    'volume_old': 0.001}],
#  'error_text': '',
#  'error_text_cargo': '',
#  'branch_from': {'id': '121', 'name': 'Москва', 'delivery': 'Да'},
#  'branch_to': {'id': '125', 'name': 'Ноябрьск', 'delivery': 'Да'},
#  'terminal_from': {'id': '121', 'name': 'Москва', 'delivery': 'Да'},
#  'terminal_to': {'id': '125', 'name': 'Ноябрьск', 'delivery': 'Да'},
#  'terminal_free_give_from': False,
#  'terminal_free_give_to': False,
#  'delivery_km_to': False,
#  'delivery_km_from': False,
#  'from_person': 'true',
#  'to_person': 'true',
#  'to_network': 'false',
#  'to_dagestan': False,
#  'from_dagestan': False,
#  'srok_link': 'https://magic-trans.ru/grafik_otpravleniya_mashin/moscow/',
#  'link_name': 'Москва - Ноябрьск',
#  'overload_to': 0,
#  'overload_to_type': '',
#  'dispatch_by_dimensions': {'take_cargo_cost': 450,
#   'give_cargo_cost': 450,
#   'give_cargo_cost_terminal': 0,
#   'give_cargo_cost_network': 0},
#  'terminal_delivery_data': {'terminal_cost_type': 'weight',
#   'terminal_price': 25.6},
#  'individual_calculation': False,
#  'calculation_data': {'hard_package': '0',
#   'packing': '0',
#   'branch_delivery': '850',
#   'take_cargo_cost': '850',
#   'give_cargo_cost': '700',
#   'give_cargo_cost_terminal': '0',
#   'give_cargo_cost_network': '0',
#   'terminal_delivery': '850',
#   'discount': '0',
#   'discount_2': 0,
#   'total_other_service': '0',
#   'total_optional_service': '40',
#   'period': '6 суток',
#   'srok_link': None,
#   'link_name': None,
#   'overload': '0',
#   'outsize': '0',
#   'test-1': '0',
#   'packing_type': '0',
#   'palletizing': '0',
#   'sensitive_cargo': '0',
#   'sensitive_cargo_take': '0',
#   'sensitive_cargo_give': '0',
#   'sensitive_cargo_network': '0',
#   'sensitive_cargo_take_give': '0',
#   'sensitive_cargo_take_network': '0',
#   'total_other_service_sensitive_cargo': '0',
#   'total_other_service_sensitive_cargo_take': '0',
#   'total_other_service_sensitive_cargo_give': '0',
#   'total_other_service_sensitive_cargo_network': '0',
#   'total_other_service_sensitive_cargo_take_give': '0',
#   'total_other_service_sensitive_cargo_take_network': '0',
#   'save': '40',
#   'return_document': '0',
#   'total_delivery_give_distance_price_from': '0',
#   'period_widget': '6',
#   'overload_from': '0',
#   'outsize_from': '0',
#   'overload_to': '0',
#   'outsize_to': '0',
#   'total_delivery_give_distance_price_to': '0',
#   'packing_type_multiplier_1_3': '0',
#   'discount_value': 0,
#   'total_delivery_with_out_other_service': '2 400',
#   'total_delivery_with_out_other_service_terminal': '1 700',
#   'total_delivery_with_out_other_service_distance_km': '1 700',
#   'total_delivery_with_out_other_service_network': '1 700',
#   'total_delivery': '2 440',
#   'total_delivery_terminal': '1 740',
#   'total_delivery_distance_price_from': '1 740',
#   'total_delivery_distance_price_from_to_network': '1 740',
#   'total_delivery_distance_price_from_to_city_give': '2 440',
#   'total_delivery_distance_price_to': '1 740',
#   'total_delivery_distance_price_all': '1 740',
#   'total_delivery_distance_price_all_without_service': '1 700',
#   'total_delivery_network': '1 740',
#   'terminal_delivery_value': 850},
#  'date_delivery': '11.05.2024',
#  'date_delivery_end': '17 мая',
#  'temp': None,
#  'delivery_routes': [],
#  'allow_COD_to': True,
#  'allow_COD_delivery_to': True,
#  'k1Calc': [],
#  'coefficient_cargo': 0.7,
#  'dispatchRegimeCoefficient': 0.5,
#  'recipientRegimeCoefficient': 0.5,
#  'coefficients': {'payload': 1.1,
#   'from': {'aeDiscount': 1,
#    'deliveryByDistance': 0,
#    'regimeAE': 0.6,
#    'regime': 0.5},
#   'to': {'aeDiscount': 1,
#    'deliveryByDistance': 0,
#    'regimeAE': 0.5,
#    'regime': 0.5},
#   'terminal': {'regime': 0.7, 'discount': 0, 'discount2': 0}},
#  'cargos': [{'length': 0,
#    'height': 0,
#    'width': 0,
#    'count': 1,
#    'weight': 30,
#    'weightOld': 30,
#    'weightTotal': 30,
#    'volume': 0.001,
#    'volumeOld': 0.001,
#    'volumeTotal': 0.001,
#    'pack': 'none',
#    'packCost': 0,
#    'palletizing': 'нет',
#    'overload': 0,
#    'overloadType': ''}],
#  'deliveryPoints': {'cities': {'from': {'id': '121',
#     'name': 'Москва',
#     'delivery': 'Да',
#     'isTerminal': 'Да',
#     'deliveryByDistance': None,
#     'distance': 0,
#     'overload': 'Да',
#     'terminal': {'id': '121', 'name': 'Москва'}},
#    'to': {'id': '125',
#     'name': 'Ноябрьск',
#     'delivery': 'Да',
#     'isTerminal': 'Да',
#     'deliveryByDistance': None,
#     'distance': 0,
#     'overload': 'Да',
#     'terminal': {'id': '125', 'name': 'Ноябрьск'}}},
#   'terminals': []},
#  'properties': {'from': {'dagestan': False,
#    'cancel': {'250': False, '500': False, '1000': False}},
#   'to': {'dagestan': False,
#    'cancel': {'250': False, '500': False, '1000': False}},
#   'fromAddress': True,
#   'toAddress': True,
#   'toMarket': False},
#  'totalCharacteristics': {'length': 0,
#   'height': 0,
#   'width': 0,
#   'weight': 30,
#   'weightOld': 30,
#   'volume': 0.001,
#   'volumeOld': 0.001,
#   'count': 1},
#  'result': {'terminal': '850',
#   'dispatch': '850',
#   'delivery': '700',
#   'toMarket': '0',
#   'pack': 0,
#   'regime': '0',
#   'overWeight': 0,
#   'overSize': 0,
#   'save': 0,
#   'returnDocuments': 0,
#   'total': '2 440',
#   'palletizing': 0,
#   'individual': False,
#   'errors': [],
#   'aeFrom': 850,
#   'aeTo': 700},
#  'isKCHR': False,
#  'isKZ': False,
#  'city_from_name_request': 'Москва',
#  'k1_test': {'valsFrom': ['2200',
#    '2000',
#    '3500',
#    '3500',
#    None,
#    '1800',
#    '1600'],
#   'valsTo': ['1000000'],
#   'stats': {'valsFrom': [2200, 2000, 3500, 3500, 1800, 1600],
#    'fromMaxWeight': 3500,
#    'valsTo': [1000000],
#    'toMaxWeight': 1000000},
#   'weights': [30],
#   'maxWeightCargo': [3500],
#   'mill': [{'l': 450, 'w': 450, 'h': 450, 'regimeCoefficient': 50},
#    'PROPERTY_DIM_04_04_04',
#    'PROPERTY_DIM_04_04_04',
#    'PROPERTY_DIM_04_04_04',
#    [450, 450, 450],
#    {'l': 450, 'w': 450, 'h': 450, 'regimeCoefficient': 50},
#    'PROPERTY_DIM_04_04_04',
#    'PROPERTY_DIM_04_04_04',
#    'PROPERTY_DIM_04_04_04',
#    [450, 450, 450],
#    {'l': 450, 'w': 450, 'h': 450, 'regimeCoefficient': 50},
#    'PROPERTY_DIM_04_04_04',
#    'PROPERTY_DIM_04_04_04',
#    'PROPERTY_DIM_04_04_04',
#    [450, 450, 450]],
#   'boxes': {'cost': {'packing': 0, 'packing_type': 0},
#    'a': None,
#    'cond': False,
#    'costReturn': {'packing': 0, 'packing_type': 0}}}}
